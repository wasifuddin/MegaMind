# %%
# !git clone https://github.com/wasifuddin/MegaMind.git
# Out:
# Cloning into 'MegaMind'...
# remote: Enumerating objects: 91, done.
# remote: Counting objects: 100% (91/91), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 91 (delta 41), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (91/91), 57.82 KiB | 2.14 MiB/s, done.
# Resolving deltas: 100% (41/41), done.

# %% [markdown]
# # Linking to Drive to Access the Detector Weights, Model Weights and The Output Footage:
#
# - Detector Weights link : [weights](https://drive.google.com/file/d/136UDAHXfV2c5xaF677lQmjaXePRbBDYl/view?usp=sharing)
#
# - Checkpoint file link : [checkpoint](https://drive.google.com/file/d/1kDKZVlSl1OrvxjG1uT4njYFQsrAhW_rF/view?usp=sharing)
#
#
#
# - Output Footage link: [output.mp4](https://drive.google.com/file/d/1-Xwt5WIqnNVRoI12RHftLNyNn_xUfWfu/view?usp=sharing)

# %%
cd MegaMind
# Out:
# /content/MegaMind

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 603.9/603.9 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 13.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 18.8 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# For testing more sample videos change the file path of video in demo.py in line no 47

# %%
# !python3 demo.py \
--input "/content/drive/MyDrive/footage.png" \
--output "/content/drive/MyDrive/res_data/pred" \
--detector-weights "/content/drive/MyDrive/res_data/person_face.pt" \
--checkpoint "/content/drive/MyDrive/res_data/model.pth.tar" \
--device "cuda:0" \
--with-persons \
--draw
# Out:
# Streaming output truncated to the last 5000 lines.
# Output  (1080, 1920, 3)
# Saved result to /content/drive/MyDrive/res_data/pred/out_4491.jpg
#
# 0: 384x640 8 persons, 2 faces, 24.4ms
# Speed: 3.9ms preprocess, 24.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# faces_input: torch.Size([8, 3, 224, 224]), person_input: torch.Size([8, 3, 224, 224])
# 	age: 42.87
# 	gender: male [99%]
# 	age: 35.0
# 	gender: female [99%]
# 	age: 41.26
# 	gender: male [99%]
# 	age: 22.53
# 	gender: male [51%]
# 	age: 33.14
# 	gender: female [99%]
# 	age: 29.73
# 	gender: female [83%]
# 	age: 32.96
# 	gender: male [99%]
# 	age: 34.37
# 	gender: male [68%]
# Output  (1080, 1920, 3)
# Saved result to /content/drive/MyDrive/res_data/pred/out_4492.jpg
#
# 0: 384x640 9 persons, 2 faces, 24.5ms
# Speed: 3.0ms preprocess, 24.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# faces_input: torch.Size([9, 3, 224, 224]), person_input: torch.Size([9, 3, 224, 224])
# ...
